# %% [markdown]
# Gabriel Marcelino, Grant Burk, and Eli Kaustinen
# September 2024
# Artificial Neural Network (ANN)

# %% [markdown]
# ## Import dependencies and load data

# %%
import sys
print(sys.path)
# Out:
# ['/Users/gabriel/Desktop/FALL2024/CST-435/Code/ANN-basketball', '/Library/Frameworks/Python.framework/Versions/3.11/lib/python311.zip', '/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11', '/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/lib-dynload', '', '/Users/gabriel/Library/Python/3.11/lib/python/site-packages', '/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages']

# %%
import csv
import random
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import numpy as np
import tensorflow as tf
from sklearn.datasets import fetch_20newsgroups
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

pool = []
training_data = []
# create pool with players from 2019-2022
with open('all_seasons.csv', mode = 'r') as file:
    csvFile = csv.reader(file)
    # ignore first line
    next(csvFile)
    for lines in csvFile:
        training_data.append(lines)

# %% [markdown]
# ## Optimal Team : Considerations
# For my optimal team, I will aim for:
# - 1 or more players in top 20% of shooting percentage.
# - Player in the top 5% out of the 100 for rebounds.
# - Player with a Defensive Rebound percentage bigger than 0.2
# - 3 or more players in top 20% of best net rating
# - 2 or more players with better than average assists

# %%
def extract_features(player):
    return {
        'name': player[1],
        'ts_pct': float(player[19]),
        'reb': float(player[13]),
        'dreb_pct': float(player[17]),
        'rating': float(player[15]),
        'ast': float(player[14])
    }

# %%
def team_score(team):
    ts_pct = np.mean([player['ts_pct'] for player in team])
    reb = np.sum([player['reb'] for player in team])
    dreb_pct = np.max([player['dreb_pct'] for player in team])
    rating = np.mean([player['rating'] for player in team])
    ast = np.sum([player['ast'] for player in team])
    # For my optimal team, the most important features are
    # 1. True shooting percentage
    # 2. Defensive rebound percentage
    # 3. Rating
    # 4. Assists/Rebounds
    score = (ts_pct * 20 + reb * 0.5 + dreb_pct * 10 + rating + ast * 0.5) / 5
    return score

def select_optimal_team(pool, team_size=5):
    player_features = [extract_features(player) for player in pool]
    
    best_team = None
    best_score = -float('inf')

    # Use a heuristic to find a good solution
    for _ in range(1000):  # Number of iterations
        team = random.sample(player_features, team_size)
        score = team_score(team)
        if score > best_score:
            best_score = score
            best_team = team

    return best_team, best_score

# %% [markdown]
# ## Model

# %%
def extract_features(pool):
    features_list = []
    for player in pool:
        # extract relevant features based on considerations above
        features = {
            'name': player[1],
            'ts_pct': player[19],
            'reb': player[13],
            'dreb_pct': player[17],
            'rating': player[15],
            'ast': player[14]
        }
        features_list.append(features)
    return features_list

# %% [markdown]
# ## Simulate Training Data to train model

# %%
def make_empty(player):
    player['ts_pct'] = 0
    player['reb'] = 0
    player['dreb_pct'] = 0
    player['rating'] = 0
    player['ast'] = 0
    return player

# %% [markdown]
# # Get Best Player for Category

# %%
def get_best(players, category):
    best_index = 0
    for cur in range(len(players)):
        if float(players[cur][category]) > float(players[best_index][category]):
            best_index = cur
    return best_index

# %% [markdown]
# # Pre Process the data

# %%
def get_datapool(segment):
    # Make testing data sets
    Xall = extract_features(training_data)
    
    # Create one training set
    X1 = []
    for i in range(100):
        X1.append(Xall[i + segment * 100])
        
    Xval = []
    for player in X1:
        Xval.append(np.array([float(player['ts_pct']), float(player['reb'])/100, float(player['dreb_pct']), float(player['rating'])/100, float(player['ast'])/100])) # extract values + normalizations 
    Xval = np.array(Xval)
    
    tempX1 = []
    for player in X1:
        tempX1.append(player.copy())
    
    # Create empty expected Y array to fill later
    Y1 = np.empty_like(X1)
    for i in range(len(Y1)):
        Y1[i] = 0
    
    # Best ts_pct into Y1
    cur = get_best(tempX1, 'ts_pct')
    tempX1[cur] = make_empty(tempX1[cur]) # Prevent repeat
    Y1[cur] = 0.9
    
    # Best reb into Y1
    cur = get_best(tempX1, 'reb')
    tempX1[cur] = make_empty(tempX1[cur]) # Prevent repeat
    Y1[cur] = 0.9
    
    # Best dreb_pct into Y1
    cur = get_best(tempX1, 'dreb_pct')
    tempX1[cur] = make_empty(tempX1[cur]) # Prevent repeat
    Y1[cur] = 0.9
    
    # Best rating into Y1
    cur = get_best(tempX1, 'rating')
    tempX1[cur] = make_empty(tempX1[cur]) # Prevent repeat
    Y1[cur] = 0.9
    
    # Best ast into Y1
    cur = get_best(tempX1, 'ast')
    tempX1[cur] = make_empty(tempX1[cur]) # Prevent repeat
    Y1[cur] = 0.9
    
    Y1 = np.array(Y1)
    
    Y1temp =  tf.convert_to_tensor(Y1, dtype=tf.float64)
    
    Xvaltemp =  tf.convert_to_tensor(Xval, dtype=tf.float64)
    
    return X1, Xvaltemp, Y1temp # return raw X (X1), processed X (Xval), and Y value (Y1

X_raw_train, X_train, y_train = get_datapool(1)
X_raw_test, X_test, y_test = get_datapool(2)

# %% [markdown]
# # Print Player Pools

# %%
print("Training Team:")
print(X_raw_train)
print()
print("Testing Team:")
print(X_raw_test)
# Out:
# Training Team:
# [{'name': 'Chris Mills', 'ts_pct': '0.544', 'reb': '6.2', 'dreb_pct': '0.157', 'rating': '4.5', 'ast': '2.5'}, {'name': 'Chris Morris', 'ts_pct': '0.486', 'reb': '2.2', 'dreb_pct': '0.155', 'rating': '-7.3', 'ast': '0.6'}, {'name': 'Chris Mullin', 'ts_pct': '0.645', 'reb': '4.0', 'dreb_pct': '0.106', 'rating': '-4.9', 'ast': '4.1'}, {'name': 'Chris Robinson', 'ts_pct': '0.486', 'reb': '1.7', 'dreb_pct': '0.08800000000000001', 'rating': '-11.4', 'ast': '1.6'}, {'name': 'Chris Webber', 'ts_pct': '0.5539999999999999', 'reb': '10.3', 'dreb_pct': '0.207', 'rating': '3.4', 'ast': '4.6'}, {'name': 'Chris Whitney', 'ts_pct': '0.5660000000000001', 'reb': '1.3', 'dreb_pct': '0.09300000000000001', 'rating': '2.0', 'ast': '2.2'}, {'name': 'Christian Laettner', 'ts_pct': '0.562', 'reb': '8.8', 'dreb_pct': '0.18600000000000003', 'rating': '11.0', 'ast': '2.7'}, {'name': 'Chucky Brown', 'ts_pct': '0.552', 'reb': '2.1', 'dreb_pct': '0.177', 'rating': '-5.9', 'ast': '0.4'}, {'name': 'Chris Gatling', 'ts_pct': '0.58', 'reb': '7.9', 'dreb_pct': '0.21600000000000003', 'rating': '-4.1', 'ast': '0.6'}, {'name': 'Clar. Weatherspoon', 'ts_pct': '0.537', 'reb': '8.3', 'dreb_pct': '0.172', 'rating': '-8.3', 'ast': '1.7'}, {'name': 'Clifford Rozier', 'ts_pct': '0.47100000000000003', 'reb': '5.6', 'dreb_pct': '0.223', 'rating': '-6.3', 'ast': '0.7'}, {'name': 'Clyde Drexler', 'ts_pct': '0.5479999999999999', 'reb': '6.0', 'dreb_pct': '0.122', 'rating': '7.5', 'ast': '5.7'}, {'name': 'Corie Blount', 'ts_pct': '0.5589999999999999', 'reb': '4.8', 'dreb_pct': '0.182', 'rating': '2.0', 'ast': '0.6'}, {'name': 'Corliss Williamson', 'ts_pct': '0.535', 'reb': '4.1', 'dreb_pct': '0.11199999999999999', 'rating': '-4.2', 'ast': '1.6'}, {'name': 'Cory Alexander', 'ts_pct': '0.528', 'reb': '1.5', 'dreb_pct': '0.081', 'rating': '-8.8', 'ast': '3.2'}, {'name': 'Craig Ehlo', 'ts_pct': '0.41200000000000003', 'reb': '1.8', 'dreb_pct': '0.107', 'rating': '5.7', 'ast': '1.1'}, {'name': 'Cuonzo Martin', 'ts_pct': '0.0', 'reb': '0.3', 'dreb_pct': '0.0', 'rating': '-12.1', 'ast': '0.3'}, {'name': 'Dale Davis', 'ts_pct': '0.532', 'reb': '9.7', 'dreb_pct': '0.215', 'rating': '-0.2', 'ast': '0.7'}, {'name': 'Dale Ellis', 'ts_pct': '0.537', 'reb': '3.6', 'dreb_pct': '0.07400000000000001', 'rating': '-9.1', 'ast': '2.0'}, {'name': 'Clifford Robinson', 'ts_pct': '0.519', 'reb': '4.0', 'dreb_pct': '0.08800000000000001', 'rating': '4.4', 'ast': '3.2'}, {'name': 'Chris Dudley', 'ts_pct': '0.449', 'reb': '7.3', 'dreb_pct': '0.249', 'rating': '-0.2', 'ast': '0.5'}, {'name': 'Chris Childs', 'ts_pct': '0.526', 'reb': '2.9', 'dreb_pct': '0.094', 'rating': '5.2', 'ast': '6.1'}, {'name': 'Chris Carr', 'ts_pct': '0.5579999999999999', 'reb': '2.1', 'dreb_pct': '0.11599999999999999', 'rating': '3.8', 'ast': '0.9'}, {'name': 'Brian Evans', 'ts_pct': '0.455', 'reb': '0.6', 'dreb_pct': '0.121', 'rating': '-12.5', 'ast': '0.5'}, {'name': 'Brian Grant', 'ts_pct': '0.511', 'reb': '5.9', 'dreb_pct': '0.185', 'rating': '-7.7', 'ast': '1.2'}, {'name': 'Brian Shaw', 'ts_pct': '0.478', 'reb': '2.5', 'dreb_pct': '0.095', 'rating': '-10.5', 'ast': '4.1'}, {'name': 'Brooks Thompson', 'ts_pct': '0.526', 'reb': '1.4', 'dreb_pct': '0.087', 'rating': '-6.2', 'ast': '2.7'}, {'name': 'Bruce Bowen', 'ts_pct': '0.0', 'reb': '0.0', 'dreb_pct': '0.0', 'rating': '300.0', 'ast': '0.0'}, {'name': 'Bryant Reeves', 'ts_pct': '0.523', 'reb': '8.1', 'dreb_pct': '0.185', 'rating': '-10.6', 'ast': '2.1'}, {'name': 'Bryant Stith', 'ts_pct': '0.5479999999999999', 'reb': '4.2', 'dreb_pct': '0.09', 'rating': '-5.6', 'ast': '2.6'}, {'name': 'Bryon Russell', 'ts_pct': '0.6', 'reb': '4.1', 'dreb_pct': '0.11800000000000001', 'rating': '13.5', 'ast': '1.5'}, {'name': 'Buck Williams', 'ts_pct': '0.574', 'reb': '5.4', 'dreb_pct': '0.184', 'rating': '6.9', 'ast': '0.7'}, {'name': 'Byron Scott', 'ts_pct': '0.59', 'reb': '1.5', 'dreb_pct': '0.075', 'rating': '6.7', 'ast': '1.3'}, {'name': 'Calbert Cheaney', 'ts_pct': '0.53', 'reb': '3.4', 'dr ...
#
# Testing Team:
# [{'name': 'Scottie Pippen', 'ts_pct': '0.5539999999999999', 'reb': '6.5', 'dreb_pct': '0.133', 'rating': '13.5', 'ast': '5.7'}, {'name': 'Sean Elliott', 'ts_pct': '0.529', 'reb': '4.9', 'dreb_pct': '0.126', 'rating': '-5.7', 'ast': '3.2'}, {'name': 'Sean Rooks', 'ts_pct': '0.547', 'reb': '2.4', 'dreb_pct': '0.166', 'rating': '1.3', 'ast': '0.6'}, {'name': 'Sedale Threatt', 'ts_pct': '0.451', 'reb': '1.1', 'dreb_pct': '0.063', 'rating': '-3.5', 'ast': '1.9'}, {'name': 'Shandon Anderson', 'ts_pct': '0.534', 'reb': '2.8', 'dreb_pct': '0.139', 'rating': '2.5', 'ast': '0.8'}, {'name': 'Shane Heal', 'ts_pct': '0.37799999999999995', 'reb': '0.4', 'dreb_pct': '0.075', 'rating': '-0.7', 'ast': '0.8'}, {'name': "Shaquille O'Neal", 'ts_pct': '0.556', 'reb': '12.5', 'dreb_pct': '0.26', 'rating': '6.9', 'ast': '3.1'}, {'name': 'Scott Brooks', 'ts_pct': '0.625', 'reb': '0.5', 'dreb_pct': '0.057999999999999996', 'rating': '3.8', 'ast': '0.8'}, {'name': 'Shareef Abdur-Rahim', 'ts_pct': '0.518', 'reb': '6.9', 'dreb_pct': '0.142', 'rating': '-12.3', 'ast': '2.2'}, {'name': 'Shawn Bradley', 'ts_pct': '0.478', 'reb': '8.4', 'dreb_pct': '0.19699999999999998', 'rating': '-5.9', 'ast': '0.7'}, {'name': 'Shawn Kemp', 'ts_pct': '0.583', 'reb': '10.0', 'dreb_pct': '0.23', 'rating': '8.9', 'ast': '1.9'}, {'name': 'Shawn Respert', 'ts_pct': '0.551', 'reb': '1.0', 'dreb_pct': '0.065', 'rating': '-4.1', 'ast': '1.0'}, {'name': 'Shawnelle Scott', 'ts_pct': '0.48', 'reb': '1.0', 'dreb_pct': '0.222', 'rating': '6.8', 'ast': '0.0'}, {'name': 'Sherman Douglas', 'ts_pct': '0.557', 'reb': '2.4', 'dreb_pct': '0.069', 'rating': '-3.0', 'ast': '5.4'}, {'name': 'Stacey Augmon', 'ts_pct': '0.531', 'reb': '2.3', 'dreb_pct': '0.109', 'rating': '6.0', 'ast': '0.9'}, {'name': 'Stacey King', 'ts_pct': '0.478', 'reb': '2.5', 'dreb_pct': '0.23199999999999998', 'rating': '-18.7', 'ast': '0.1'}, {'name': 'Stanley Roberts', 'ts_pct': '0.485', 'reb': '5.1', 'dreb_pct': '0.218', 'rating': '2.6', 'ast': '0.5'}, {'name': 'Stephen Howard', 'ts_pct': '0.613', 'reb': '1.7', 'dreb_pct': '0.16399999999999998', 'rating': '0.1', 'ast': '0.2'}, {'name': 'Sharone Wright', 'ts_pct': '0.423', 'reb': '3.1', 'dreb_pct': '0.126', 'rating': '-9.3', 'ast': '0.5'}, {'name': 'Sasha Danilovic', 'ts_pct': '0.552', 'reb': '2.4', 'dreb_pct': '0.069', 'rating': '1.5', 'ast': '1.8'}, {'name': 'Sarunas Marciulionis', 'ts_pct': '0.496', 'reb': '1.8', 'dreb_pct': '0.086', 'rating': '-7.6', 'ast': '1.5'}, {'name': 'Samaki Walker', 'ts_pct': '0.485', 'reb': '3.4', 'dreb_pct': '0.198', 'rating': '-12.6', 'ast': '0.4'}, {'name': 'Rex Walters', 'ts_pct': '0.5710000000000001', 'reb': '1.8', 'dreb_pct': '0.09300000000000001', 'rating': '-11.1', 'ast': '1.9'}, {'name': 'Richard Manning', 'ts_pct': '0.425', 'reb': '1.5', 'dreb_pct': '0.136', 'rating': '-6.8', 'ast': '0.1'}, {'name': 'Rick Fox', 'ts_pct': '0.551', 'reb': '5.2', 'dreb_pct': '0.134', 'rating': '-6.9', 'ast': '3.8'}, {'name': 'Rick Mahorn', 'ts_pct': '0.44', 'reb': '2.4', 'dreb_pct': '0.192', 'rating': '-0.1', 'ast': '0.3'}, {'name': 'Ricky Pierce', 'ts_pct': '0.583', 'reb': '2.0', 'dreb_pct': '0.078', 'rating': '-1.6', 'ast': '1.3'}, {'name': 'Rik Smits', 'ts_pct': '0.535', 'reb': '6.9', 'dreb_pct': '0.201', 'rating': '1.4', 'ast': '1.3'}, {'name': 'Robert Horry', 'ts_pct': '0.529', 'reb': '4.4', 'dreb_pct': '0.14300000000000002', 'rating': '2.7', 'ast': '2.0'}, {'name': 'Robert Pack', 'ts_pct': '0.48200000000000004', 'reb': '2.7', 'dreb_pct': '0.078', 'rating': '-8.3', 'ast': '8.4'}, {'name': 'Robert Parish', 'ts_pct': '0.514', 'reb': '2.1', 'dreb_pct': '0.13', 'rating': '14.9', 'ast': '0.5'}, {'name': 'Robert Werdann', 'ts_pct': '0.541', 'reb': '1.0', 'dreb_pct': '0.14300000000000002', 'rating': '-14.5', 'ast': '0.0'}, {'name': 'Rod Strickland', 'ts_pct': '0.5329999999999999', 'reb': '4.1', 'dreb_pct': '0.09300000000000001', 'rating': '1.7', 'ast': '8.9'}, {'name': 'Rodney Rogers', 'ts_pct': '0.53', 'reb': '5.1', 'dreb_pct': '0.132', 'rating': '-3.5', ...

# %% [markdown]
# ## Train Model
# Now that we have the training data, we can train the model.

# %%
# 3. Neural Network Model
model = tf.keras.models.Sequential([
    # Input Layer (implicitly present by specifying input_shape)
    
    # Hidden Layer 1
    tf.keras.layers.Dense(100, activation='relu'),
    
    # Hidden Layer 2
    tf.keras.layers.Dense(100, activation='relu'),
    
    # Output Layer
    tf.keras.layers.Dense(1, activation='sigmoid')  # Binary classification
])

# 4. Compile the Model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# 5. Train the Model
for i in range(10):
    for j in range(10):
        _, X_temp, y_temp = get_datapool(j)
        model.fit(X_temp, y_temp, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9416 - loss: 0.6752
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9571 - loss: 0.6161
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9467 - loss: 0.5600
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step - accuracy: 0.9446 - loss: 0.5121
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9540 - loss: 0.4570
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 972us/step - accuracy: 0.9415 - loss: 0.4174
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9415 - loss: 0.3681
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9540 - loss: 0.3117
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9477 - loss: 0.2830
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step - accuracy: 0.9540 - loss: 0.2342
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9592 - loss: 0.2080
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9560 - loss: 0.1946
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9467 - loss: 0.2092
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9571 - loss: 0.1760
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9435 - loss: 0.1992
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - accuracy: 0.9290 - loss: 0.2368
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9508 - loss: 0.1731
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9540 - loss: 0.1614
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9446 - loss: 0.1841
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9508 - loss: 0.1754
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9602 - loss: 0.1619
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step - accuracy: 0.9529 - loss: 0.1834
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step - accuracy: 0.9352 - loss: 0.2443
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - accuracy: 0.9540 - loss: 0.1821
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9498 - loss: 0.1879
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9477 - loss: 0.1966
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9571 - loss: 0.1738
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9477 - loss: 0.2058
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 911us/step - accuracy: 0.9571 - loss: 0.1748
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 899us/step - accuracy: 0.9415 - loss: 0.2215
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9446 - loss: 0.1966
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - accuracy: 0.9404 - loss: 0.2082
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9540 - loss: 0.1718
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.9352 - loss: 0.2217
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 853us/step - accuracy: 0.9602 - loss: 0.1538
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9540 - loss: 0.1688
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 918us/step - accuracy: 0.9571 - loss: 0.1584
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 807us/step - accuracy: 0.9467 - loss: 0.1872
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step - accuracy: 0.9477 - loss: 0.1838
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 841us/step - accuracy: 0.9540 - loss: 0.1626
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 920us/step - accuracy: 0.9415 - loss: 0.2420
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9560 - loss: 0.1855
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9508 - loss: 0.2112
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - accuracy: 0.9415 - loss: 0.2369
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step - accuracy: 0.9540 - loss: 0.1901
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step - accuracy: 0.9383 - loss: 0.2427
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - accuracy: 0.9685 - loss: 0.1495
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step - accuracy: 0.9529 - loss: 0.1993
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9685 - loss: 0.1477
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9383 - loss: 0.2339
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9623 - loss: 0.1587
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9540 - loss: 0.1747
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9467 - loss: 0.1887
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step - accuracy: 0.9540 - loss: 0.1836
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - accuracy: 0.9602 - loss: 0.1625
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - accuracy: 0.9415 - loss: 0.2085
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 921us/step - accuracy: 0.9633 - loss: 0.1493
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step - accuracy: 0.9321 - loss: 0.2208
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 960us/step - accuracy: 0.9529 - loss: 0.1636
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step - accuracy: 0.9477 - loss: 0.1808
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9383 - loss: 0.2062
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9540 - loss: 0.1576
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9540 - loss: 0.1693
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9571 - loss: 0.1585
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 992us/step - accuracy: 0.9415 - loss: 0.1984
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9477 - loss: 0.1825
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 920us/step - accuracy: 0.9477 - loss: 0.1691
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - accuracy: 0.9508 - loss: 0.1782
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 905us/step - accuracy: 0.9446 - loss: 0.1701
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9446 - loss: 0.1808
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9477 - loss: 0.1783
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step - accuracy: 0.9633 - loss: 0.1309
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9415 - loss: 0.1893
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9540 - loss: 0.1558
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9592 - loss: 0.1387
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.9654 - loss: 0.1276
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - accuracy: 0.9415 - loss: 0.1775
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9415 - loss: 0.1826
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 898us/step - accuracy: 0.9477 - loss: 0.1677
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 813us/step - accuracy: 0.9540 - loss: 0.1451
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9383 - loss: 0.1576
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step - accuracy: 0.9508 - loss: 0.1435
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step - accuracy: 0.9540 - loss: 0.1332
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9571 - loss: 0.1265
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 958us/step - accuracy: 0.9498 - loss: 0.1383
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9352 - loss: 0.1643
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step - accuracy: 0.9665 - loss: 0.0992
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 941us/step - accuracy: 0.9467 - loss: 0.1399
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step - accuracy: 0.9633 - loss: 0.1033
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9446 - loss: 0.1437
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step - accuracy: 0.9602 - loss: 0.1546
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step - accuracy: 0.9508 - loss: 0.1714
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - accuracy: 0.9571 - loss: 0.1415
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9508 - loss: 0.2059
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step - accuracy: 0.9592 - loss: 0.1600
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step - accuracy: 0.9498 - loss: 0.1627
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 857us/step - accuracy: 0.9352 - loss: 0.2314
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9290 - loss: 0.2181
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9571 - loss: 0.1425
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 953us/step - accuracy: 0.9415 - loss: 0.2061
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 969us/step - accuracy: 0.9477 - loss: 0.1770
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - accuracy: 0.9446 - loss: 0.1865
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - accuracy: 0.9477 - loss: 0.1803
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 948us/step - accuracy: 0.9623 - loss: 0.1473
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step - accuracy: 0.9477 - loss: 0.1806
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9623 - loss: 0.1534
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 995us/step - accuracy: 0.9508 - loss: 0.1846
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step - accuracy: 0.9467 - loss: 0.1803
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 982us/step - accuracy: 0.9592 - loss: 0.1727
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.9383 - loss: 0.2139
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9477 - loss: 0.1409
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step - accuracy: 0.9467 - loss: 0.1622
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 963us/step - accuracy: 0.9519 - loss: 0.1414
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9477 - loss: 0.1395
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - accuracy: 0.9383 - loss: 0.1431
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step - accuracy: 0.9498 - loss: 0.1313
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9540 - loss: 0.1271
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step - accuracy: 0.9665 - loss: 0.0960
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step - accuracy: 0.9571 - loss: 0.1140
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 868us/step - accuracy: 0.9633 - loss: 0.1004
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step - accuracy: 0.9571 - loss: 0.1589
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 942us/step - accuracy: 0.9633 - loss: 0.1459
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9508 - loss: 0.1965
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 863us/step - accuracy: 0.9415 - loss: 0.2174
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - accuracy: 0.9540 - loss: 0.1845
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step - accuracy: 0.9508 - loss: 0.1629
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 966us/step - accuracy: 0.9571 - loss: 0.1760
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - accuracy: 0.9644 - loss: 0.1370
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9446 - loss: 0.1976
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 974us/step - accuracy: 0.9633 - loss: 0.1523
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9352 - loss: 0.1797
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 889us/step - accuracy: 0.9540 - loss: 0.1585
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9508 - loss: 0.1434
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step - accuracy: 0.9383 - loss: 0.1700
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9508 - loss: 0.1439
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9446 - loss: 0.1645
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 855us/step - accuracy: 0.9290 - loss: 0.1893
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9477 - loss: 0.1567
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9383 - loss: 0.1797
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 895us/step - accuracy: 0.9477 - loss: 0.1512
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - accuracy: 0.9508 - loss: 0.1746
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - accuracy: 0.9321 - loss: 0.2353
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step - accuracy: 0.9446 - loss: 0.1956
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9540 - loss: 0.1644
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step - accuracy: 0.9508 - loss: 0.1648
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 905us/step - accuracy: 0.9383 - loss: 0.2030
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9540 - loss: 0.1605
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9613 - loss: 0.1455
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 967us/step - accuracy: 0.9571 - loss: 0.1369
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9383 - loss: 0.1918
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step - accuracy: 0.9477 - loss: 0.1490
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9415 - loss: 0.1804
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step - accuracy: 0.9685 - loss: 0.1062
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 894us/step - accuracy: 0.9540 - loss: 0.1386
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9383 - loss: 0.1770
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9602 - loss: 0.1305
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9571 - loss: 0.1255
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9540 - loss: 0.1449
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step - accuracy: 0.9571 - loss: 0.1272
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9571 - loss: 0.1300
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step - accuracy: 0.9571 - loss: 0.1353
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9571 - loss: 0.1325
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step - accuracy: 0.9383 - loss: 0.1668
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step - accuracy: 0.9540 - loss: 0.1408
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 969us/step - accuracy: 0.9654 - loss: 0.1245
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9477 - loss: 0.1412
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9623 - loss: 0.1164
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step - accuracy: 0.9571 - loss: 0.1346
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9352 - loss: 0.1934
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9508 - loss: 0.1316
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 843us/step - accuracy: 0.9477 - loss: 0.1264
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step - accuracy: 0.9477 - loss: 0.1351
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 921us/step - accuracy: 0.9446 - loss: 0.1362
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 951us/step - accuracy: 0.9571 - loss: 0.1130
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step - accuracy: 0.9571 - loss: 0.1169
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 953us/step - accuracy: 0.9477 - loss: 0.1504
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step - accuracy: 0.9415 - loss: 0.1405
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step - accuracy: 0.9446 - loss: 0.1278
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step - accuracy: 0.9633 - loss: 0.1089
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step - accuracy: 0.9383 - loss: 0.1316
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step - accuracy: 0.9477 - loss: 0.1184
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 862us/step - accuracy: 0.9446 - loss: 0.1278
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - accuracy: 0.9383 - loss: 0.1347
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step - accuracy: 0.9477 - loss: 0.1184
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step - accuracy: 0.9415 - loss: 0.1222
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - accuracy: 0.9498 - loss: 0.1093
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 841us/step - accuracy: 0.9415 - loss: 0.1192
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9477 - loss: 0.1086
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 849us/step - accuracy: 0.9665 - loss: 0.0879
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9508 - loss: 0.1083
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9571 - loss: 0.1657
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 943us/step - accuracy: 0.9508 - loss: 0.1540
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 899us/step - accuracy: 0.9415 - loss: 0.2025
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9654 - loss: 0.1043
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 943us/step - accuracy: 0.9508 - loss: 0.1560
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9540 - loss: 0.1211
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 911us/step - accuracy: 0.9540 - loss: 0.1685
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9540 - loss: 0.1375
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9415 - loss: 0.1499
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9446 - loss: 0.1372
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 959us/step - accuracy: 0.9383 - loss: 0.1996
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - accuracy: 0.9383 - loss: 0.2032
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - accuracy: 0.9477 - loss: 0.1904
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step - accuracy: 0.9633 - loss: 0.1369
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9446 - loss: 0.1745
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step - accuracy: 0.9383 - loss: 0.1782
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9508 - loss: 0.1773
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - accuracy: 0.9477 - loss: 0.1810
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9435 - loss: 0.1691
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9571 - loss: 0.1601
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9592 - loss: 0.1240
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9477 - loss: 0.1310
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9446 - loss: 0.1323
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9508 - loss: 0.1171
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step - accuracy: 0.9540 - loss: 0.1063
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9571 - loss: 0.1185
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step - accuracy: 0.9685 - loss: 0.0950
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9540 - loss: 0.1341
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9696 - loss: 0.0819
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9508 - loss: 0.1229
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step - accuracy: 0.9477 - loss: 0.1905
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9383 - loss: 0.2149
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 889us/step - accuracy: 0.9560 - loss: 0.1383
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 960us/step - accuracy: 0.9540 - loss: 0.1807
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - accuracy: 0.9623 - loss: 0.1462
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9529 - loss: 0.1786
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - accuracy: 0.9540 - loss: 0.1642
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step - accuracy: 0.9477 - loss: 0.1782
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9550 - loss: 0.1728
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9477 - loss: 0.1652
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - accuracy: 0.9540 - loss: 0.1284
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9665 - loss: 0.1136
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step - accuracy: 0.9571 - loss: 0.1299
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9383 - loss: 0.1656
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 865us/step - accuracy: 0.9477 - loss: 0.1492
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step - accuracy: 0.9508 - loss: 0.1358
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 995us/step - accuracy: 0.9571 - loss: 0.1247
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step - accuracy: 0.9654 - loss: 0.1020
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 995us/step - accuracy: 0.9383 - loss: 0.1686
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9477 - loss: 0.1380
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 844us/step - accuracy: 0.9508 - loss: 0.1404
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - accuracy: 0.9571 - loss: 0.1296
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9592 - loss: 0.1187
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - accuracy: 0.9477 - loss: 0.1226
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9415 - loss: 0.1506
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - accuracy: 0.9383 - loss: 0.1455
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - accuracy: 0.9383 - loss: 0.1709
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - accuracy: 0.9446 - loss: 0.1301
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9540 - loss: 0.1299
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 857us/step - accuracy: 0.9477 - loss: 0.1359
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9498 - loss: 0.1176
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9290 - loss: 0.1775
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step - accuracy: 0.9415 - loss: 0.1530
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9540 - loss: 0.1218
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step - accuracy: 0.9446 - loss: 0.1534
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 992us/step - accuracy: 0.9383 - loss: 0.1587
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 838us/step - accuracy: 0.9540 - loss: 0.1083
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - accuracy: 0.9477 - loss: 0.1148
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 855us/step - accuracy: 0.9623 - loss: 0.1053
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step - accuracy: 0.9435 - loss: 0.1537
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step - accuracy: 0.9354 - loss: 0.1782
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 894us/step - accuracy: 0.9229 - loss: 0.1967
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step - accuracy: 0.9468 - loss: 0.1357
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step - accuracy: 0.9508 - loss: 0.1212
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 972us/step - accuracy: 0.9540 - loss: 0.1550
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 967us/step - accuracy: 0.9352 - loss: 0.1608
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 807us/step - accuracy: 0.9592 - loss: 0.1172
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step - accuracy: 0.9508 - loss: 0.1484
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 992us/step - accuracy: 0.9415 - loss: 0.1381
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step - accuracy: 0.9529 - loss: 0.1228
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step - accuracy: 0.9665 - loss: 0.1000
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step - accuracy: 0.9529 - loss: 0.1232
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9540 - loss: 0.1041
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 911us/step - accuracy: 0.9602 - loss: 0.0918
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 846us/step - accuracy: 0.9560 - loss: 0.0885
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step - accuracy: 0.9477 - loss: 0.1172
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 858us/step - accuracy: 0.9477 - loss: 0.1056
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 951us/step - accuracy: 0.9477 - loss: 0.1041
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step - accuracy: 0.9633 - loss: 0.0940
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step - accuracy: 0.9477 - loss: 0.1339
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step - accuracy: 0.9498 - loss: 0.0944
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step - accuracy: 0.9415 - loss: 0.1205
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 919us/step - accuracy: 0.9477 - loss: 0.1032
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step - accuracy: 0.9415 - loss: 0.1097
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step - accuracy: 0.9571 - loss: 0.0851
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step - accuracy: 0.9592 - loss: 0.0835
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9477 - loss: 0.0937
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9446 - loss: 0.0989
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step - accuracy: 0.9571 - loss: 0.0799
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - accuracy: 0.9529 - loss: 0.0717
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 821us/step - accuracy: 0.9540 - loss: 0.1430
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - accuracy: 0.9685 - loss: 0.1095
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step - accuracy: 0.9633 - loss: 0.1197
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step - accuracy: 0.9508 - loss: 0.1421
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - accuracy: 0.9227 - loss: 0.2082
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9477 - loss: 0.1411
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - accuracy: 0.9508 - loss: 0.1717
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 858us/step - accuracy: 0.9498 - loss: 0.1373
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9508 - loss: 0.1233
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step - accuracy: 0.9571 - loss: 0.1265
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 953us/step - accuracy: 0.9477 - loss: 0.1684
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 824us/step - accuracy: 0.9383 - loss: 0.1863
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9415 - loss: 0.1659
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 895us/step - accuracy: 0.9352 - loss: 0.1749
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 944us/step - accuracy: 0.9477 - loss: 0.1488
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9446 - loss: 0.1669
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - accuracy: 0.9446 - loss: 0.1533
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - accuracy: 0.9477 - loss: 0.1634
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - accuracy: 0.9508 - loss: 0.1476
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step - accuracy: 0.9498 - loss: 0.1354
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9633 - loss: 0.1020
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step - accuracy: 0.9415 - loss: 0.1553
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9592 - loss: 0.0981
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step - accuracy: 0.9321 - loss: 0.1409
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 865us/step - accuracy: 0.9508 - loss: 0.1083
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9446 - loss: 0.1069
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step - accuracy: 0.9571 - loss: 0.1174
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 952us/step - accuracy: 0.9498 - loss: 0.1137
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 899us/step - accuracy: 0.9352 - loss: 0.1401
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - accuracy: 0.9571 - loss: 0.1098
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step - accuracy: 0.9665 - loss: 0.1229
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9352 - loss: 0.2061
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 982us/step - accuracy: 0.9592 - loss: 0.1395
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step - accuracy: 0.9498 - loss: 0.1429
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - accuracy: 0.9415 - loss: 0.1664
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9477 - loss: 0.1727
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step - accuracy: 0.9633 - loss: 0.1405
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step - accuracy: 0.9446 - loss: 0.1800
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 824us/step - accuracy: 0.9467 - loss: 0.1781
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step - accuracy: 0.9592 - loss: 0.1233
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step - accuracy: 0.9540 - loss: 0.1207
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step - accuracy: 0.9415 - loss: 0.1439
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step - accuracy: 0.9602 - loss: 0.1208
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.9519 - loss: 0.1154
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 780us/step - accuracy: 0.9352 - loss: 0.1532
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step - accuracy: 0.9437 - loss: 0.1213
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 945us/step - accuracy: 0.9323 - loss: 0.1323
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step - accuracy: 0.9291 - loss: 0.1390
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 862us/step - accuracy: 0.9540 - loss: 0.1179
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step - accuracy: 0.9571 - loss: 0.1223
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9540 - loss: 0.1243
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - accuracy: 0.9508 - loss: 0.1147
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step - accuracy: 0.9560 - loss: 0.1263
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9446 - loss: 0.1340
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 807us/step - accuracy: 0.9477 - loss: 0.1395
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 898us/step - accuracy: 0.9477 - loss: 0.1310
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 824us/step - accuracy: 0.9540 - loss: 0.1251
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - accuracy: 0.9508 - loss: 0.1267
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9227 - loss: 0.1690
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 853us/step - accuracy: 0.9415 - loss: 0.1562
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9477 - loss: 0.1258
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9446 - loss: 0.1122
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step - accuracy: 0.9467 - loss: 0.1310
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 790us/step - accuracy: 0.9498 - loss: 0.1199
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - accuracy: 0.9477 - loss: 0.1261
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 898us/step - accuracy: 0.9540 - loss: 0.0959
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step - accuracy: 0.9696 - loss: 0.0843
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step - accuracy: 0.9508 - loss: 0.1073
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9446 - loss: 0.1028
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step - accuracy: 0.9383 - loss: 0.1257
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9477 - loss: 0.1239
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - accuracy: 0.9508 - loss: 0.1103
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step - accuracy: 0.9602 - loss: 0.1024
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step - accuracy: 0.9290 - loss: 0.1679
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step - accuracy: 0.9352 - loss: 0.1353
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 789us/step - accuracy: 0.9540 - loss: 0.0995
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step - accuracy: 0.9352 - loss: 0.1252
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 980us/step - accuracy: 0.9498 - loss: 0.1367
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step - accuracy: 0.9633 - loss: 0.1011
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 811us/step - accuracy: 0.9571 - loss: 0.0918
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9383 - loss: 0.1385
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 903us/step - accuracy: 0.9383 - loss: 0.1246
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step - accuracy: 0.9508 - loss: 0.0991
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step - accuracy: 0.9633 - loss: 0.0915
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 841us/step - accuracy: 0.9633 - loss: 0.0798
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step - accuracy: 0.9508 - loss: 0.0978
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - accuracy: 0.9477 - loss: 0.1037
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 859us/step - accuracy: 0.9446 - loss: 0.1330
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 769us/step - accuracy: 0.9508 - loss: 0.0995
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step - accuracy: 0.9540 - loss: 0.1232
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step - accuracy: 0.9540 - loss: 0.0918
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step - accuracy: 0.9477 - loss: 0.1044
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 919us/step - accuracy: 0.9508 - loss: 0.0810
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 865us/step - accuracy: 0.9508 - loss: 0.0785
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step - accuracy: 0.9352 - loss: 0.1010
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - accuracy: 0.9415 - loss: 0.0830
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 769us/step - accuracy: 0.9477 - loss: 0.0815
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 923us/step - accuracy: 0.9477 - loss: 0.0849
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step - accuracy: 0.9540 - loss: 0.0800
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 968us/step - accuracy: 0.9467 - loss: 0.0927
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 827us/step - accuracy: 0.9540 - loss: 0.1348
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 810us/step - accuracy: 0.9602 - loss: 0.1551
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9602 - loss: 0.1088
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9498 - loss: 0.1126
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - accuracy: 0.9508 - loss: 0.1135
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step - accuracy: 0.9446 - loss: 0.1607
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step - accuracy: 0.9592 - loss: 0.1095
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9383 - loss: 0.1440
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step - accuracy: 0.9498 - loss: 0.1020
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step - accuracy: 0.9321 - loss: 0.1466
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 932us/step - accuracy: 0.9541 - loss: 0.1149
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9437 - loss: 0.1285
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step - accuracy: 0.9323 - loss: 0.1587
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 809us/step - accuracy: 0.9416 - loss: 0.1285
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step - accuracy: 0.9260 - loss: 0.1612
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - accuracy: 0.9437 - loss: 0.1395
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 863us/step - accuracy: 0.9416 - loss: 0.1146
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step - accuracy: 0.9312 - loss: 0.1304
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9416 - loss: 0.1381
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 971us/step - accuracy: 0.9448 - loss: 0.1200
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step - accuracy: 0.9227 - loss: 0.1641
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9383 - loss: 0.1229
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 865us/step - accuracy: 0.9352 - loss: 0.1299
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step - accuracy: 0.9602 - loss: 0.0971
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step - accuracy: 0.9446 - loss: 0.1063
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9498 - loss: 0.1216
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step - accuracy: 0.9623 - loss: 0.0766
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step - accuracy: 0.9540 - loss: 0.0993
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step - accuracy: 0.9633 - loss: 0.0813
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 854us/step - accuracy: 0.9508 - loss: 0.0960
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 903us/step - accuracy: 0.9529 - loss: 0.1224
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9383 - loss: 0.1631
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step - accuracy: 0.9415 - loss: 0.1504
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step - accuracy: 0.9508 - loss: 0.1342
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 787us/step - accuracy: 0.9571 - loss: 0.1272
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step - accuracy: 0.9477 - loss: 0.1396
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9571 - loss: 0.1256
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 795us/step - accuracy: 0.9571 - loss: 0.1136
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step - accuracy: 0.9540 - loss: 0.1272
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step - accuracy: 0.9540 - loss: 0.1341
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9508 - loss: 0.1308
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step - accuracy: 0.9665 - loss: 0.0991
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 863us/step - accuracy: 0.9508 - loss: 0.1192
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step - accuracy: 0.9498 - loss: 0.1176
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 769us/step - accuracy: 0.9446 - loss: 0.1324
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 932us/step - accuracy: 0.9468 - loss: 0.1195
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step - accuracy: 0.9229 - loss: 0.1416
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9479 - loss: 0.1076
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9498 - loss: 0.1053
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - accuracy: 0.9562 - loss: 0.0824
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 794us/step - accuracy: 0.9321 - loss: 0.1379
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9540 - loss: 0.1141
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step - accuracy: 0.9446 - loss: 0.1265
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step - accuracy: 0.9446 - loss: 0.1242
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 822us/step - accuracy: 0.9446 - loss: 0.1198
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step - accuracy: 0.9415 - loss: 0.1208
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step - accuracy: 0.9592 - loss: 0.1064
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 963us/step - accuracy: 0.9654 - loss: 0.0836
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 855us/step - accuracy: 0.9571 - loss: 0.1120
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step - accuracy: 0.9385 - loss: 0.1097
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 984us/step - accuracy: 0.9352 - loss: 0.0986
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9446 - loss: 0.0806
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 796us/step - accuracy: 0.9383 - loss: 0.0976
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step - accuracy: 0.9508 - loss: 0.0976
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step - accuracy: 0.9415 - loss: 0.1142
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step - accuracy: 0.9540 - loss: 0.0787
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9540 - loss: 0.0761
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step - accuracy: 0.9477 - loss: 0.0814
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - accuracy: 0.9529 - loss: 0.0726
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9477 - loss: 0.0812
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step - accuracy: 0.9043 - loss: 0.1483
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step - accuracy: 0.9323 - loss: 0.1219
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9540 - loss: 0.1024
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 995us/step - accuracy: 0.9383 - loss: 0.1439
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9560 - loss: 0.1077
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9383 - loss: 0.1438
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9479 - loss: 0.0900
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9510 - loss: 0.1048
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9385 - loss: 0.1032
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9352 - loss: 0.1053
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9602 - loss: 0.1012
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9540 - loss: 0.1170
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9571 - loss: 0.0981
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9540 - loss: 0.0979
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9415 - loss: 0.1349
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9613 - loss: 0.1042
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 845us/step - accuracy: 0.9385 - loss: 0.0910
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - accuracy: 0.9262 - loss: 0.1113
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9283 - loss: 0.1141
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step - accuracy: 0.9166 - loss: 0.1260
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - accuracy: 0.9477 - loss: 0.0905
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9352 - loss: 0.1072
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 972us/step - accuracy: 0.9477 - loss: 0.0783
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9508 - loss: 0.0823
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9508 - loss: 0.0713
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9477 - loss: 0.0919
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step - accuracy: 0.9529 - loss: 0.0660
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9665 - loss: 0.0529
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9290 - loss: 0.1009
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step - accuracy: 0.9540 - loss: 0.0743
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 836us/step - accuracy: 0.9508 - loss: 0.1586
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9383 - loss: 0.1725
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - accuracy: 0.9446 - loss: 0.1578
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9446 - loss: 0.1422
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9415 - loss: 0.1743
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9602 - loss: 0.0989
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 898us/step - accuracy: 0.9560 - loss: 0.0838
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step - accuracy: 0.9435 - loss: 0.0950
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step - accuracy: 0.9531 - loss: 0.1067
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9295 - loss: 0.1298
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step - accuracy: 0.9385 - loss: 0.1259
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 970us/step - accuracy: 0.9385 - loss: 0.1120
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9290 - loss: 0.1643
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9415 - loss: 0.1439
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9290 - loss: 0.1640
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9446 - loss: 0.1174
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step - accuracy: 0.9633 - loss: 0.0842
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step - accuracy: 0.9385 - loss: 0.1113
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - accuracy: 0.9448 - loss: 0.0890
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9540 - loss: 0.0898
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step - accuracy: 0.9415 - loss: 0.1264
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9415 - loss: 0.1253
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9571 - loss: 0.1041
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9383 - loss: 0.1479
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9404 - loss: 0.1042
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9540 - loss: 0.0905
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 899us/step - accuracy: 0.9560 - loss: 0.0983
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step - accuracy: 0.9383 - loss: 0.1175
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9477 - loss: 0.1030
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 822us/step - accuracy: 0.9613 - loss: 0.0821
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 959us/step - accuracy: 0.9571 - loss: 0.1192
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9540 - loss: 0.1083
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step - accuracy: 0.9404 - loss: 0.1223
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9498 - loss: 0.1239
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9540 - loss: 0.1214
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 923us/step - accuracy: 0.9415 - loss: 0.1343
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 918us/step - accuracy: 0.9498 - loss: 0.1160
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9696 - loss: 0.0822
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9446 - loss: 0.1313
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step - accuracy: 0.9592 - loss: 0.1020
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9571 - loss: 0.1013
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step - accuracy: 0.9323 - loss: 0.1357
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 918us/step - accuracy: 0.9323 - loss: 0.1225
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9571 - loss: 0.1012
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9571 - loss: 0.1076
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 984us/step - accuracy: 0.9529 - loss: 0.0965
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 863us/step - accuracy: 0.9477 - loss: 0.1122
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9166 - loss: 0.1471
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9387 - loss: 0.0992
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 920us/step - accuracy: 0.9416 - loss: 0.1054
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 806us/step - accuracy: 0.9477 - loss: 0.0961
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step - accuracy: 0.9560 - loss: 0.1226
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9415 - loss: 0.1307
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - accuracy: 0.9592 - loss: 0.0956
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - accuracy: 0.9448 - loss: 0.0859
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step - accuracy: 0.9416 - loss: 0.0924
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9541 - loss: 0.0817
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9508 - loss: 0.1304
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 984us/step - accuracy: 0.9540 - loss: 0.1122
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 808us/step - accuracy: 0.9560 - loss: 0.0874
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 823us/step - accuracy: 0.9415 - loss: 0.0676
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9446 - loss: 0.0728
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step - accuracy: 0.9529 - loss: 0.0700
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 941us/step - accuracy: 0.9508 - loss: 0.0659
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 934us/step - accuracy: 0.9415 - loss: 0.0722
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9415 - loss: 0.0713
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 951us/step - accuracy: 0.9633 - loss: 0.0481
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9508 - loss: 0.0631
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step - accuracy: 0.9540 - loss: 0.0531
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9508 - loss: 0.0551
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 795us/step - accuracy: 0.9395 - loss: 0.1239
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step - accuracy: 0.9385 - loss: 0.1005
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step - accuracy: 0.9415 - loss: 0.1196
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9540 - loss: 0.0906
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 832us/step - accuracy: 0.9602 - loss: 0.0853
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step - accuracy: 0.9508 - loss: 0.0962
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step - accuracy: 0.9446 - loss: 0.1000
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9477 - loss: 0.0791
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 921us/step - accuracy: 0.9415 - loss: 0.1046
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9602 - loss: 0.0840
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 988us/step - accuracy: 0.9387 - loss: 0.0856
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9293 - loss: 0.0899
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9479 - loss: 0.0818
# Epoch 4/10
# ...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step - accuracy: 0.9323 - loss: 0.0949
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - accuracy: 0.9477 - loss: 0.0861
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9477 - loss: 0.0959
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9446 - loss: 0.0880
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 782us/step - accuracy: 0.9446 - loss: 0.0985
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9446 - loss: 0.0805
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9560 - loss: 0.0743
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9383 - loss: 0.0855
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9435 - loss: 0.0671
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9446 - loss: 0.0697
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - accuracy: 0.9508 - loss: 0.0745
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 824us/step - accuracy: 0.9446 - loss: 0.0967
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9665 - loss: 0.0763
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9415 - loss: 0.1136
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9446 - loss: 0.0951
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9508 - loss: 0.0918
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9477 - loss: 0.0755
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step - accuracy: 0.9446 - loss: 0.0965
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9477 - loss: 0.0904
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 788us/step - accuracy: 0.9383 - loss: 0.0940
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9508 - loss: 0.0838
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - accuracy: 0.9500 - loss: 0.0866
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9416 - loss: 0.1179
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - accuracy: 0.9263 - loss: 0.1265
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9107 - loss: 0.1186
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step - accuracy: 0.9418 - loss: 0.0864
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9343 - loss: 0.1081
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9189 - loss: 0.1194
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9437 - loss: 0.0860
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step - accuracy: 0.9416 - loss: 0.0849
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step - accuracy: 0.9201 - loss: 0.0885
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step - accuracy: 0.9477 - loss: 0.1095
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 923us/step - accuracy: 0.9446 - loss: 0.1099
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 806us/step - accuracy: 0.9383 - loss: 0.1152
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9602 - loss: 0.0797
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step - accuracy: 0.9477 - loss: 0.0857
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step - accuracy: 0.9508 - loss: 0.0905
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step - accuracy: 0.9498 - loss: 0.1023
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9540 - loss: 0.0892
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step - accuracy: 0.9571 - loss: 0.0809
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 911us/step - accuracy: 0.9477 - loss: 0.0884
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - accuracy: 0.9519 - loss: 0.0808
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9354 - loss: 0.0702
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 951us/step - accuracy: 0.9416 - loss: 0.0758
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step - accuracy: 0.9446 - loss: 0.0670
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9540 - loss: 0.0613
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9592 - loss: 0.0533
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 896us/step - accuracy: 0.9665 - loss: 0.0426
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step - accuracy: 0.9560 - loss: 0.0451
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 918us/step - accuracy: 0.9508 - loss: 0.0469
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9685 - loss: 0.0486
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 812us/step - accuracy: 0.8859 - loss: 0.1446
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9284 - loss: 0.1094
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step - accuracy: 0.9437 - loss: 0.1051
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step - accuracy: 0.9446 - loss: 0.0948
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step - accuracy: 0.9446 - loss: 0.1281
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step - accuracy: 0.9383 - loss: 0.1263
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 786us/step - accuracy: 0.9571 - loss: 0.0715
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9571 - loss: 0.0644
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 813us/step - accuracy: 0.9602 - loss: 0.0582
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step - accuracy: 0.9477 - loss: 0.0698
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step - accuracy: 0.9230 - loss: 0.1013
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 832us/step - accuracy: 0.9283 - loss: 0.0875
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step - accuracy: 0.9168 - loss: 0.0884
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 899us/step - accuracy: 0.9189 - loss: 0.0983
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9449 - loss: 0.0727
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 846us/step - accuracy: 0.9220 - loss: 0.0961
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9355 - loss: 0.0721
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 787us/step - accuracy: 0.9220 - loss: 0.0822
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9199 - loss: 0.0729
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step - accuracy: 0.9387 - loss: 0.0614
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - accuracy: 0.9508 - loss: 0.0909
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9571 - loss: 0.0679
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9446 - loss: 0.0842
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 889us/step - accuracy: 0.9571 - loss: 0.0519
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step - accuracy: 0.9477 - loss: 0.0587
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 830us/step - accuracy: 0.9602 - loss: 0.0561
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step - accuracy: 0.9633 - loss: 0.0581
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9446 - loss: 0.0876
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9383 - loss: 0.0998
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9529 - loss: 0.0747
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9446 - loss: 0.0947
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9592 - loss: 0.0584
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 942us/step - accuracy: 0.9540 - loss: 0.0656
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step - accuracy: 0.9602 - loss: 0.0624
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step - accuracy: 0.9665 - loss: 0.0460
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 836us/step - accuracy: 0.9508 - loss: 0.0638
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9467 - loss: 0.0590
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9477 - loss: 0.0600
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step - accuracy: 0.9435 - loss: 0.0623
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9602 - loss: 0.0537
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step - accuracy: 0.9562 - loss: 0.0704
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - accuracy: 0.9406 - loss: 0.0923
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 947us/step - accuracy: 0.9126 - loss: 0.1181
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9479 - loss: 0.0771
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step - accuracy: 0.9416 - loss: 0.0897
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 865us/step - accuracy: 0.9437 - loss: 0.0688
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 971us/step - accuracy: 0.9633 - loss: 0.0607
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 781us/step - accuracy: 0.9508 - loss: 0.0920
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 858us/step - accuracy: 0.9446 - loss: 0.0885
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step - accuracy: 0.9323 - loss: 0.0738
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9415 - loss: 0.0885
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9508 - loss: 0.0952
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9477 - loss: 0.1017
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9581 - loss: 0.0720
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - accuracy: 0.9383 - loss: 0.0920
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9540 - loss: 0.0715
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 846us/step - accuracy: 0.9571 - loss: 0.0596
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step - accuracy: 0.9415 - loss: 0.0656
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9560 - loss: 0.0543
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9540 - loss: 0.0553
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - accuracy: 0.9477 - loss: 0.0897
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - accuracy: 0.9529 - loss: 0.0968
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 894us/step - accuracy: 0.9446 - loss: 0.0896
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step - accuracy: 0.9571 - loss: 0.0784
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step - accuracy: 0.9477 - loss: 0.0807
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9498 - loss: 0.0958
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step - accuracy: 0.9529 - loss: 0.0687
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step - accuracy: 0.9540 - loss: 0.0787
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 903us/step - accuracy: 0.9446 - loss: 0.0888
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 781us/step - accuracy: 0.9477 - loss: 0.0741
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 849us/step - accuracy: 0.9437 - loss: 0.1252
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - accuracy: 0.9448 - loss: 0.1185
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9437 - loss: 0.1160
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 846us/step - accuracy: 0.9323 - loss: 0.1171
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step - accuracy: 0.9508 - loss: 0.1178
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 947us/step - accuracy: 0.9540 - loss: 0.0875
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 839us/step - accuracy: 0.9560 - loss: 0.0909
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step - accuracy: 0.9168 - loss: 0.1200
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.9107 - loss: 0.0940
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9387 - loss: 0.0825
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 834us/step - accuracy: 0.9383 - loss: 0.1396
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - accuracy: 0.9446 - loss: 0.1201
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 793us/step - accuracy: 0.9508 - loss: 0.1093
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 911us/step - accuracy: 0.9696 - loss: 0.0635
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.9291 - loss: 0.1026
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9385 - loss: 0.0955
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 973us/step - accuracy: 0.9500 - loss: 0.0719
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - accuracy: 0.9448 - loss: 0.0792
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - accuracy: 0.9323 - loss: 0.0989
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 737us/step - accuracy: 0.9541 - loss: 0.0795
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 806us/step - accuracy: 0.9406 - loss: 0.0651
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step - accuracy: 0.9529 - loss: 0.0599
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9477 - loss: 0.0664
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step - accuracy: 0.9633 - loss: 0.0495
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step - accuracy: 0.9508 - loss: 0.0542
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step - accuracy: 0.9508 - loss: 0.0482
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step - accuracy: 0.9623 - loss: 0.0386
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 894us/step - accuracy: 0.9467 - loss: 0.0425
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 823us/step - accuracy: 0.9415 - loss: 0.0596
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9291 - loss: 0.0764
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 788us/step - accuracy: 0.9138 - loss: 0.1234
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - accuracy: 0.9418 - loss: 0.0745
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step - accuracy: 0.9354 - loss: 0.1139
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 837us/step - accuracy: 0.9508 - loss: 0.0931
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step - accuracy: 0.9571 - loss: 0.0673
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 789us/step - accuracy: 0.9383 - loss: 0.0890
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9477 - loss: 0.0941
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 862us/step - accuracy: 0.9540 - loss: 0.0687
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 760us/step - accuracy: 0.9383 - loss: 0.0803
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 835us/step - accuracy: 0.9477 - loss: 0.0842
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - accuracy: 0.9323 - loss: 0.0971
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 837us/step - accuracy: 0.9324 - loss: 0.0811
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - accuracy: 0.9448 - loss: 0.0705
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9137 - loss: 0.0929
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9323 - loss: 0.0715
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 859us/step - accuracy: 0.9323 - loss: 0.0816
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 896us/step - accuracy: 0.9448 - loss: 0.0673
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 815us/step - accuracy: 0.9479 - loss: 0.0635
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step - accuracy: 0.9291 - loss: 0.0790
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - accuracy: 0.9448 - loss: 0.0635
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - accuracy: 0.9633 - loss: 0.0616
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 793us/step - accuracy: 0.9498 - loss: 0.0855
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 841us/step - accuracy: 0.9508 - loss: 0.0599
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 808us/step - accuracy: 0.9498 - loss: 0.0733
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9354 - loss: 0.0736
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step - accuracy: 0.9540 - loss: 0.0697
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step - accuracy: 0.9477 - loss: 0.0609
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - accuracy: 0.9571 - loss: 0.0526
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - accuracy: 0.9477 - loss: 0.0633
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9571 - loss: 0.0531
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - accuracy: 0.9415 - loss: 0.0802
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step - accuracy: 0.9477 - loss: 0.0696
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9529 - loss: 0.0597
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 863us/step - accuracy: 0.9477 - loss: 0.0538
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 841us/step - accuracy: 0.9477 - loss: 0.0624
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step - accuracy: 0.9446 - loss: 0.0537
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9654 - loss: 0.0369
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step - accuracy: 0.9571 - loss: 0.0410
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9529 - loss: 0.0411
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 923us/step - accuracy: 0.9383 - loss: 0.0545

# %% [markdown]
# # Print Team

# %%
# Training Data
print("Actual Best Team:")
for i in range(len(y_train)):
    if(y_train[i] > 0):
        print(X_raw_train[i])
print()

print("Predicted Best Team:")
predicted_y = model.predict(X_train)
for i in range(len(predicted_y)):
    if(predicted_y[i][0] > 0.5):
        print(X_raw_train[i]['name'])
        print(predicted_y[i])
# Out:
# Actual Best Team:
# {'name': 'Chris Mullin', 'ts_pct': '0.645', 'reb': '4.0', 'dreb_pct': '0.106', 'rating': '-4.9', 'ast': '4.1'}
# {'name': 'Bruce Bowen', 'ts_pct': '0.0', 'reb': '0.0', 'dreb_pct': '0.0', 'rating': '300.0', 'ast': '0.0'}
# {'name': 'Charles Barkley', 'ts_pct': '0.581', 'reb': '13.5', 'dreb_pct': '0.28', 'rating': '7.5', 'ast': '4.7'}
# {'name': 'Damon Stoudamire', 'ts_pct': '0.516', 'reb': '4.1', 'dreb_pct': '0.09', 'rating': '-3.7', 'ast': '8.8'}
# {'name': 'Dennis Rodman', 'ts_pct': '0.479', 'reb': '16.1', 'dreb_pct': '0.32299999999999995', 'rating': '16.1', 'ast': '3.1'}
#
# Predicted Best Team:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Bruce Bowen
# [0.99999166]
# Charles Barkley
# [0.85233736]
# Dennis Rodman
# [0.9155663]

# %%
# Testing Data
print("Actual Best Team:")
for i in range(len(y_test)):
    if(y_test[i] > 0):
        print(X_raw_test[i])
print()

print("Predicted Best Team:")
predicted_y = model.predict(X_test)
for i in range(len(predicted_y)):
    if(predicted_y[i][0] > 0.5):
        print(X_raw_test[i]['name'])
        print(predicted_y[i])
# Out:
# Actual Best Team:
# {'name': "Shaquille O'Neal", 'ts_pct': '0.556', 'reb': '12.5', 'dreb_pct': '0.26', 'rating': '6.9', 'ast': '3.1'}
# {'name': 'Rod Strickland', 'ts_pct': '0.5329999999999999', 'reb': '4.1', 'dreb_pct': '0.09300000000000001', 'rating': '1.7', 'ast': '8.9'}
# {'name': 'Will Perdue', 'ts_pct': '0.5820000000000001', 'reb': '9.8', 'dreb_pct': '0.25', 'rating': '-4.7', 'ast': '0.6'}
# {'name': 'Steve Scheffler', 'ts_pct': '0.799', 'reb': '0.4', 'dreb_pct': '0.077', 'rating': '-19.9', 'ast': '0.0'}
# {'name': 'Litterial Green', 'ts_pct': '0.531', 'reb': '0.5', 'dreb_pct': '0.055', 'rating': '17.0', 'ast': '0.9'}
#
# Predicted Best Team:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 498us/step
# Steve Scheffler
# [0.92165273]

# %% [markdown]
# ## Explain your architecture and how the basketball player characteristics are used as inputs:
#
# 1. Data Preparation:
#
# - Pool and Training Data:
#     - Separates data:
#         - `pool` holds 100 unique players (2019-2022) for potential future use.
#         - `training_data` stores up to 5000 players (2019-2022) for model training.
#
# 2. Feature Extraction:
#
# - The `extract_features` function takes a list of players and creates a dictionary of features for each one.
# - These features include:
#     - Name (not used as input)
#     - True Shooting Percentage (ts_pct)
#     - Rebounds (reb)
#     - Defensive Rebound Percentage (dreb_pct)
#     - Net Rating (rating)
#     - Assists (ast)
#
# 3. Simulating Data for Training:
#
# - The `simulate_data` function generates training data with labels indicating successful teams based on pre-defined criteria.
# - It takes a list of players (`sample`) and a number of simulations (`num_iter`).
# - Here's how player characteristics are used as inputs:
#     - Averages and percentiles are calculated for assists, shooting percentage, rebounds, and net rating from the `sample` data.
#     - Loops through `num_iter` simulations:
#         - Selects 5 random players.
#         - Extracts their features using `extract_features`.
#         - Assigns a label (0 or 1) based on the criteria defined above..
#
# 4. Model Building and Training:
#
# TO-DO
# 5. Evaluation:
#
# TO-DO

# %% [markdown]
# ## Interpret the output of your MLP in the context of selecting an optimal basketball team:
#
# This MLP is trained on the 'optimal' prediction, given the input features of the dataset-shooting percentage, rebounds, assists, and player ratings amongst others-a basketball lineup is optimal. These mentioned inputs provide key indications about player performance. The model will process it for a binary outcome; 1 stands for an optimum team, and 0 stands for a suboptimum team. It could be shown that the MLP model is currently trained to learn from historical data to understand whether a combination of players is strong or weak and thus provide insight into which lineups will perform likely perform.
#
# These could then inform the choice of an optimum basketball team, where the model shows which sets of players are statistically balanced in key performance metrics. The teams that are predicted as "optimal" will indicate that their set of players is effective, while those labeled "suboptimal" need adjustment. Coaches or team selectors would be able to play around with different mixes of players in order to fine-tune their strategy and ensure the team is great in a lot of aspects of the game: scoring, defense, teamwork, just to name a few.
#
# Besides the precision, recall is one of the metrics that signifies model reliability or accuracy. High accuracy means the model can discriminate between good and bad lineups well. While precision and recall give an indication of few false predictions or missing optimal teams, in the end, what an MLP model provides is a data-driven method of selection of the team so as to best ensure that the lineup chosen will perform better on the court.
