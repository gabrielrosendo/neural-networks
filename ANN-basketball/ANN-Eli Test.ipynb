# %% [markdown]
# Gabriel Marcelino, Grant Burk, and Eli Kaustinen
# September 2024
# Artificial Neural Network (ANN)

# %%
import csv
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Load data
pool = []
with open('all_seasons.csv', mode='r') as file:
    csvFile = csv.reader(file)
    next(csvFile)  # Skip header
    for lines in csvFile:
        pool.append(lines)

# Extract features and labels
def extract_features_and_labels(pool):
    features = []
    labels = []
    for player in pool:
        features.append([
            float(player[19]),  # ts_pct
            float(player[13]),  # reb
            float(player[17]),  # dreb_pct
            float(player[15]),  # rating
            float(player[14])   # ast
        ])
        labels.append(float(player[15]))  # Use rating as the label for simplicity
    return np.array(features), np.array(labels)

features, labels = extract_features_and_labels(pool)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

# Standardize the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Build the ANN model
model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='linear'))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(X_train, y_train, epochs=50, batch_size=10, validation_split=0.2)

# Predict scores for all players
all_features = scaler.transform(features)
predicted_scores = model.predict(all_features)

# Select the top 5 players based on predicted scores
player_scores = [(pool[i][1], predicted_scores[i][0]) for i in range(len(pool))]
player_scores.sort(key=lambda x: x[1], reverse=True)
top_players = player_scores[:5]

# Print the top 5 players
for player, score in top_players:
    print(f"Player: {player}, Predicted Score: {score}")
# Out:
# Epoch 1/50
# d:\Users\Busters\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 1s 522us/step - loss: 88.1927 - val_loss: 4.5572
# Epoch 2/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 0s 429us/step - loss: 1.7634 - val_loss: 1.2001
# Epoch 3/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 0s 429us/step - loss: 0.3616 - val_loss: 0.3545
# Epoch 4/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 0s 444us/step - loss: 0.1497 - val_loss: 0.1712
# Epoch 5/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 0s 426us/step - loss: 0.0964 - val_loss: 0.0935
# Epoch 6/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 0s 429us/step - loss: 0.0655 - val_loss: 0.0571
# Epoch 7/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 0s 444us/step - loss: 0.1328 - val_loss: 0.1275
# Epoch 8/50
# ...
